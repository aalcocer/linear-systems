# %%
# %matplotlib inline

#from IPython.html.widgets import interact, fixed
import ipywidgets 

#import matplotlib
import numpy as np
#import sympy
#from sympy import *
#from control import matlab
#import control
#import scipy
import matplotlib.pyplot as plt
#import seaborn; seaborn.set()

# %%
x=np.linspace(0,1,500)
f=2

plt.figure()
plt.plot(x,np.sin(2*np.pi*x*f));

# %%
def pltsin(f):
    plt.plot(x,np.sin(2*np.pi*x*f))

# %%
ipywidgets.interact(pltsin, f=(1,10,0.1));
